# %%
import sys
sys.path.append('${TDL_ROOT_DIR}/results')

from Trainer import Trainer

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())

# %%
trainer = Trainer(
    dataset='MNIST',
    hidden_dims=[512]*8,
    act_fn=jax.nn.tanh,
    study_name='512x8_tanh',
    num_epochs=50,
    batch_size=64
)

# %%
mean_activations = trainer.class_mean_activations(dataset=trainer.full_dataset, class_label=3, model_id=0)

import pickle
with open('${TDL_ROOT_DIR}/results/MNIST/class_mean_activations/class_3.pkl', 'wb') as f:
    pickle.dump(mean_activations, f)

# %%
recons = trainer.recons_from_means(
    model_id=0,
    class_label=3,
    num_samples=3
)

# %%
recons = trainer.recons_from_means(
    model_id=0,
    class_label=3,
    num_samples=3,
    lr_h=0.1,
    lr_x=0.1
)

# %%
recons = trainer.recons_from_means(
    model_id=0,
    class_label=3,
    num_samples=3,
    noise_sigma=0.5,
    T=200,
    lr_h=0.005,
    lr_x=0.02
)

# %%
recons = trainer.recons_from_means(
    model_id=0,
    class_label=3,
    num_samples=3,
    noise_sigma=0.3,
    T=250
)
