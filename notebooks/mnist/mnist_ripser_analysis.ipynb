# %%
# import dill
# with open('${TDL_ROOT_DIR}/results/MNIST/512x8_relu/ripser_k8_d2/model_0.dill', 'rb') as f:
#     rips = dill.load(f)

# %%
import sys
sys.path.append('${TDL_ROOT_DIR}/results')

from Trainer import Trainer

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())

# %%
trainer = Trainer(
    dataset='MNIST',
    hidden_dims=[512]*8,
    act_fn=jax.nn.relu,
    study_name='512x8_relu',
    num_epochs=50,
    batch_size=64
)

# import dill
# with open(f'{trainer.root}/data/data_by_class/label_0_1500.dill', 'rb') as f:
#     dataset = dill.load(f)

# trainer.run_ripser(dataset=dataset, dir_name='ripser_k8_d2', k=8, maxdim=2, thresh=15, num_models=1)

# %%
trainer.graph_betti_numbers(dir_name='ripser_k8_d2', k=8, maxdim=2, etas=range(1, 10))
