# %%
import sys
sys.path.append('${TDL_ROOT_DIR}/results')

from Trainer import Trainer

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())

# %%
Trainer.all_bootstrap_stats(
    filename='test_run4',
    studies=['512_32_relu', '512_32_leaky'],
    dataset='MNIST',
    dir_name='ripser_class_0_norm'
)

# %%
import dill

with open('${TDL_ROOT_DIR}/results/MNIST/512_32_relu/ripser_class_0_norm/model_0.dill', 'rb') as f:
    norm = dill.load(f)

with open('${TDL_ROOT_DIR}/results/MNIST/512_32_relu/ripser_k3/label_0/model_0.dill', 'rb') as f:
    k3 = dill.load(f)

# %%
print(norm[0][0])
print()
print(k3[0][0])
